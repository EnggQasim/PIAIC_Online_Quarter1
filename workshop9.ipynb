# %% [raw]
# Topics:
#     function
#         function decleration
#         function body
#         function calling
#
#     pre define function
#         return function
#         Non return function
#             defualt function
#             required arguments
#             postional/keyword arguments
#             optional arguments
#     User define function
#         Same as above

# %% [markdown]
# # why we need of function in programming?

# %%
print("pakistan zinda bad")
print("We are pakistani")
print("We love our country")
# Out:
# pakistan zinda bad
# We are pakistani
# We love our country

# %%
print("pakistan zinda bad")
print("We are pakistani")
print("We love our country")

print("pakistan zinda bad")
print("We are pakistani")
print("We love our country")
print("pakistan zinda bad")
print("We are pakistani")
print("We love our country")
# Out:
# pakistan zinda bad
# We are pakistani
# We love our country
# pakistan zinda bad
# We are pakistani
# We love our country
# pakistan zinda bad
# We are pakistani
# We love our country

# %% [markdown]
# # Now Create Function:

# %%
# we have created defual user define fucntion.

def abc(): # function decleration
    print("pakistan zinda bad") #function body 
    print("We are pakistani")
    print("We love our country")# function body
    
abc() # function calling   
print("========")
print("Hello World!")
abc()
# Out:
# pakistan zinda bad
# We are pakistani
# We love our country
# ========
# Hello World!
# pakistan zinda bad
# We are pakistani
# We love our country

# %% [markdown]
# # Return Vs Non Return Function:

# %%
a = print("Pakistan") #Non Return
print(a)
# Out:
# Pakistan
# None

# %%
def abc(): # function decleration
    print("pakistan zinda bad") #function body 
    print("We are pakistani")
    print("We love our country")# function body
    
a = abc() # Non Return Fuction    
print(a)
# Out:
# pakistan zinda bad
# We are pakistani
# We love our country
# None

# %%
a = input("Enter any number") # Return Fucntion
print(a)
# Out:
# Enter any number25
# 25

# %%
a = int("27") # Return Function
type(a) # Return Function
# Out:
# int

# %% [markdown]
# # Required Argument Function

# %%
def add_two_numbers(n1,n2):
    return n1 + n2

a = add_two_numbers(2,3) #return function
print(a)

a = add_two_numbers(2,5) #return function
print(a)

a = add_two_numbers(5,9) #return function
print(a)
# Out:
# 5
# 7
# 14

# %%
def add_two_numbers(n1,n2):
    print(n1 + n2)
    
a = add_two_numbers(2,3) #return function
print(a)
# Out:
# 5
# None

# %%
add_two_numbers(8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-688736e0be58> in <module>
# ----> 1 add_two_numbers(8)
#
# TypeError: add_two_numbers() missing 1 required positional argument: 'n2'

# %% [markdown]
# # postional Argument
# - def add_two_numbers(n1,n2):
# - add_two_numbers(6,7)   # n1=6, n2=7

# %%
add_two_numbers(6,7)
# Out:
# 13

# %%
def subtract_n1_n2(n1,n2):
    return n1 - n2

print(subtract_n1_n2(7,3))
print(subtract_n1_n2(5,12))
# Out:
# 4
# -7

# %% [markdown]
# ##### Passing key word argument

# %%
def subtract_n1_n2(n1,n2):
    return n1 - n2

print(subtract_n1_n2(n1=7,n2=3))
print(subtract_n1_n2(n2=5,n1=12))
# Out:
# 4
# 7

# %%
def card(id, name, fname, course):
    return """
    PIAIC Student Card
    Name: {}
    Fahter's Name: {}
    Course: {}
    Timing: {}
    """.format(id,name,fname, course)

print(card(1,"Qasim","Aslam","A.I"))
# Out:
#     PIAIC Student Card
#     Name: 1
#     Fahter's Name: Qasim
#     Course: Aslam
#     Timing: A.I

# %%
print(card(12,"Aslam","Qasim","A.I"))
# Out:
#     PIAIC Student Card
#     Name: 12
#     Fahter's Name: Aslam
#     Course: Qasim
#     Timing: A.I

# %%
print(card(name="Qasim", id=7, fname="Aslam", course="A.I"))
# Out:
#     PIAIC Student Card
#     Name: 7
#     Fahter's Name: Qasim
#     Course: Aslam
#     Timing: A.I

# %%
card(1,'A')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-610f95a20cfe> in <module>
# ----> 1 card(1,'A')
#
# TypeError: card() missing 2 required positional arguments: 'fname' and 'course'

# %% [markdown]
# ##### pass postional argument with list

# %%
def card(id, name, fname, course):
    return """
    PIAIC Student Card
    Name: {}
    Fahter's Name: {}
    Course: {}
    Timing: {}
    """.format(id,name,fname, course)

# %%
l1 = [0,"Asif","Abid Khan", "A.I"]

print(card(l1[0], l1[1], l1[2], l1[3]))
# Out:
#     PIAIC Student Card
#     Name: 0
#     Fahter's Name: Asif
#     Course: Abid Khan
#     Timing: A.I

# %%
l1 = [0,"Asif","Abid Khan", "A.I"]
print(card(*l1))
# Out:
#     PIAIC Student Card
#     Name: 0
#     Fahter's Name: Asif
#     Course: Abid Khan
#     Timing: A.I

# %%
l1 = (0,"Asif","Abid Khan", "A.I")

print(card(*l1))
# Out:
#     PIAIC Student Card
#     Name: 0
#     Fahter's Name: Asif
#     Course: Abid Khan
#     Timing: A.I

# %% [markdown]
# ##### pass keyword arguments with dictionary

# %%
def card(sid, name, fname, course):
    return """
    PIAIC Student Card
    Id: {}
    Name: {}
    Fahter's Name: {}
    Course: {}
    """.format(sid,name,fname, course)

# %%
dic = {'name':'Qasim',
      'fname':"Aslam",
      'course':"A.I",
      'sid': 27}

print(card(**dic))
# Out:
#     PIAIC Student Card
#     Id: 27
#     Name: Qasim
#     Fahter's Name: Aslam
#     Course: A.I

# %% [markdown]
# ### set defual argument values

# %%
def xyz_add(x=0, y=0, z=0):
    print(x,y,z)
    return x+y+z

xyz_add(2,9)
# Out:
# 2 9 0
# 11

# %%
xyz_add(8,20,5)
# Out:
# 8 20 5
# 33

# %%
xyz_add()
# Out:
# 0 0 0
# 0

# %% [markdown]
# # Create function with unlimited parameters

# %%
def add_numbers(n1, *l):
    return n1 + sum(l)

add_numbers(2)
# Out:
# 2

# %%
add_numbers(2,8)
# Out:
# 10

# %%
add_numbers(2,9,9,38,3,2,2,3,4,3)
# Out:
# 75

# %%
add_numbers(2,n2=3,n3=6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-a053184f3ecc> in <module>
# ----> 1 add_numbers(2,n2=3,n3=6)
#
# TypeError: add_numbers() got an unexpected keyword argument 'n2'

# %%
# Create function with unlimited parameters (key words)
def add_key_numbers(n1, **d):
    l1 = []
    l1.append(n1)
    
    print(d)
    for k, v in d.items():
        l1.append(d[k])
        
    return sum(l1)

add_key_numbers(n1=7,n2=3,n3=7,n6=7)
# Out:
# {'n2': 3, 'n3': 7, 'n6': 7}
# 24
